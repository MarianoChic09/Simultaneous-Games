# %%
from games.mp import MP
# from agents.regretmatching import RegretMatching
from agents.fictitiousplay import FictitiousPlay
from agents.random_agent import RandomAgent

# %%
g = MP()

# %%
g.reset()
# Out:
# ({'agent_0': None, 'agent_1': None}, None)

# %%
rm = dict(map(lambda agent: (agent, RegretMatching(game=g, agent=agent, seed=1)), g.agents))

# %%
for i in range(10000):
    actions = dict(map(lambda agent: (agent, rm[agent].action()), g.agents))
    g.step(actions)

# %%
dict(map(lambda agent: (agent, rm[agent].policy()), g.agents))

# %%
agent_classes = [ RegretMatching, RandomAgent ]
my_agents = {}
g.reset()
for i, agent in enumerate(g.agents):
    my_agents[agent] = agent_classes[i](game=g, agent=agent)

# %%
for i in range(10000):
    actions = dict(map(lambda agent: (agent, my_agents[agent].action()), g.agents))
    g.step(actions)

# %%
dict(map(lambda agent: (agent, my_agents[agent].policy()), g.agents))

# %%
g.reset()
# Out:
# ({'agent_0': None, 'agent_1': None}, None)

# %%
fp = dict(map(lambda agent: (agent, FictitiousPlay(game=g, agent=agent, seed=1)), g.agents))

# %%
for i in range(10000):
    actions = dict(map(lambda agent: (agent, fp[agent].action()), g.agents))
    g.step(actions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[110], line 2
#       1 for i in range(10000):
# ----> 2     actions = dict(map(lambda agent: (agent, fp[agent].action()), g.agents))
#       3     g.step(actions)
#
# Cell In[110], line 2, in <lambda>(agent)
#       1 for i in range(10000):
# ----> 2     actions = dict(map(lambda agent: (agent, fp[agent].action()), g.agents))
#       3     g.step(actions)
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:69, in FictitiousPlay.action(self)
#      67 def action(self):
#      68     self.update()
# ---> 69     return self.bestresponse()
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:49, in FictitiousPlay.bestresponse(self)
#      48 def bestresponse(self):
# ---> 49     utility = self.get_utility()
#      50     a = np.argmax(utility)
#      52     return a
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:44, in FictitiousPlay.get_utility(self)
#      40 for joint_action in rewards.keys(): #product(*[range(self.game.num_actions(a)) for a in self.game.agents]):
#      41     # if joint_action[self.agent] == action:
#      42     # actions = dict(map(lambda agent: (agent, act[g.agent_name_mapping[agent]]), g.agents))
#      43     action = joint_action[self.game.agent_name_mapping[self.agent]]
# ---> 44     prob = np.prod([self.learned_policy[other_agent][joint_action[self.game.agent_name_mapping[other_agent]]] for other_agent in self.game.agents if other_agent != self.agent])
#      45     utility[action] += rewards[joint_action] * prob
#      46 return utility
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:44, in <listcomp>(.0)
#      40 for joint_action in rewards.keys(): #product(*[range(self.game.num_actions(a)) for a in self.game.agents]):
#      41     # if joint_action[self.agent] == action:
#      42     # actions = dict(map(lambda agent: (agent, act[g.agent_name_mapping[agent]]), g.agents))
#      43     action = joint_action[self.game.agent_name_mapping[self.agent]]
# ---> 44     prob = np.prod([self.learned_policy[other_agent][joint_action[self.game.agent_name_mapping[other_agent]]] for other_agent in self.game.agents if other_agent != self.agent])
#      45     utility[action] += rewards[joint_action] * prob
#      46 return utility
#
# IndexError: invalid index to scalar variable.

# %%
dict(map(lambda agent: (agent, fp[agent].policy()), g.agents))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import agents.fictitiousplay
reload(agents.fictitiousplay)
import games.mp
reload(games.mp)
from agents.fictitiousplay import FictitiousPlay
from games.mp import MP

# %%
agent_classes = [ FictitiousPlay, RandomAgent ]
my_agents = {}
g.reset()
for i, agent in enumerate(g.agents):
    my_agents[agent] = agent_classes[i](game=g, agent=agent)

# %%
my_agents
# Out:
# {'agent_0': <agents.fictitiousplay.FictitiousPlay at 0x2110a881f50>,
#  'agent_1': <agents.random_agent.RandomAgent at 0x2110c351b50>}

# %%
for i in range(10000):
    actions = dict(map(lambda agent: (agent, my_agents[agent].action()), g.agents))
    g.step(actions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 for i in range(10000):
# ----> 2     actions = dict(map(lambda agent: (agent, my_agents[agent].action()), g.agents))
#       3     g.step(actions)
#
# Cell In[79], line 2, in <lambda>(agent)
#       1 for i in range(10000):
# ----> 2     actions = dict(map(lambda agent: (agent, my_agents[agent].action()), g.agents))
#       3     g.step(actions)
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:65, in FictitiousPlay.action(self)
#      63 def action(self):
#      64     self.update()
# ---> 65     return self.bestresponse()
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:46, in FictitiousPlay.bestresponse(self)
#      45 def bestresponse(self):
# ---> 46     utility = self.get_utility()
#      47     a = np.argmax(utility)
#      49     return a
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:35, in FictitiousPlay.get_utility(self)
#      34 def get_utility(self):
# ---> 35     rewards = self.get_rewards()
#      36     utility = np.zeros(self.game.num_actions(self.agent))
#      38     for action in range(self.game.num_actions(self.agent)):
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\agents\fictitiousplay.py:30, in FictitiousPlay.get_rewards(self)
#      28 rewards: dict[tuple, float] = {}
#      29 for joint_action in product(*agents_actions):
# ---> 30     g.step(joint_action)
#      31     rewards[joint_action] = g.reward(self.agent)
#      32 return rewards
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\games\mp.py:35, in step(self, actions)
#      27 self.action_to_index = {
#      28     'H': 0,
#      29     'T': 1
#      30 }
#      32 # observations
#      33 self.observation_spaces = {
#      34     agent: ActionDict for agent in self.agents
# ---> 35 }
#
# File c:\Users\scruple077\OneDrive\Master en Big Data - Universidad ORT\3er Semestre\Sistemas Multiagente\Simultaneous Games\Simultaneous Games\games\mp.py:35, in MP.step.<locals>.<lambda>(agent)
#      32 def step(self, actions: ActionDict) -> tuple[ObsDict, dict[str, float], dict[str, bool], dict[str, bool], dict[str, dict]]:
#      33     # rewards
#      34     # (a0, a1) = tuple(map(lambda agent: self.action_to_index[actions[agent]], self.agents))
# ---> 35     (a0, a1) = tuple(map(lambda agent: actions[agent], self.agents))
#      36     r = self._R[a0][a1]
#      37     self.rewards[self.agents[0]] = r
#
# TypeError: tuple indices must be integers or slices, not str

# %%
dict(map(lambda agent: (agent, my_agents[agent].policy()), g.agents))
